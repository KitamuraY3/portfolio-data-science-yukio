# %% [markdown]
# 🎯 **Objetivo principal do projeto**
#
# Este notebook tem como objetivo realizar uma análise univariada das variáveis numéricas do dataset clássico Iris, utilizando técnicas de visualização de dados para:
#
# - Explorar a distribuição individual de cada variável,
# - Observar tendências, dispersão e possíveis outliers,
# - Aplicar boas práticas visuais com bibliotecas como Matplotlib e Seaborn,
# - Produzir interpretações escritas claras e objetivas, com qualidade profissional.
#
# Este notebook serve como **primeira etapa** de uma série de análises, podendo futuramente evoluir para análises bivariadas e multivariadas.
#
# - SUMÁRIO:
#     1. Biliotecas
#     2. Dataset
#     3. Análise descritiva inicial
#     4. Visualizações univariadas com gráficos.
#         4.1 Histogramas
#         4.2 Boxplots
#     5. Conclusão

# %% [markdown]
# # 1. BIBLIOTECAS:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. DATASET:

# %%
# CARREGAR O DATASET 'Iris' DO SCIKIT-LEARN:
from sklearn.datasets import load_iris

# DATASET:
iris_raw = load_iris(as_frame=True)
iris = iris_raw.frame

# TRANSFORMAR O TARGET DE CÓDIGO PARA O NOME REAL DAS ESPÉCIES:
iris['species'] = iris_raw.target_names[iris['target']]

# DROP DA COLUNA'target' (CÓDIGO NUMÉRICO), AGORA TEMOS A 'species':
iris.drop(columns='target', inplace=True)

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %% [markdown]
# ### 🔍 Estrutura do dataset Iris
#
# O dataset contém 150 amostras de flores, divididas igualmente entre 3 espécies:
#
# - **setosa**
# - **versicolor**
# - **virginica**
#
# Cada flor é descrita por 4 variáveis numéricas:
#
# - Comprimento da sépala (`sepal length (cm)`)
# - Largura da sépala (`sepal width (cm)`)
# - Comprimento da pétala (`petal length (cm)`)
# - Largura da pétala (`petal width (cm)`)

# %% [markdown]
# # 3. ANÁLISE DESCRITIVA INICIAL:

# %%
# DESCRIBE:
iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ### 📈 Resumo Estatístico – Variáveis Numéricas
#
# A tabela acima mostra que:
#
# - O comprimento da pétala (`petal length`) apresenta grande variação, com média de aproximadamente 3,76 cm e desvio padrão comparativamente elevado de 1,77 cm.
# - Já a largura da sépala (`sepal width`) tem menor dispersão (desvio padrão de 0,44 cm) e distribuição mais concentrada.
# - Algumas variáveis, como `sepal width`, podem conter outliers (diferença grande entre `min` e `25%`).

# %% [markdown]
# # 4. VISUALIZAÇÕES UNIVARIADAS COM GRÁFICOS:

# %% [markdown]
# ## 4.1. HISTOGRAMAS:

# %% [markdown]
# ### 4.1.1. HISTOGRAMA 'sepal length':

# %%
plt.figure(figsize=(8, 5))
plt.grid(True, linestyle='-', alpha=0.5)
sns.histplot(data=iris, x='sepal length (cm)', bins=20, kde=True)

plt.title('Distribuição do Comprimento da Sépala', fontsize=14)
plt.xlabel('Comprimento da Sépala (cm)')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📌 Interpretação: `sepal length (cm)`
#
# - A distribuição do comprimento da sépala é aproximadamente simétrica, com concentração entre 5,0 e 6,5 cm.
# - A curva de densidade indica que não há grandes picos ou caudas pronunciadas, sugerindo uma distribuição próxima da normal.
# - Não há evidências claras de outliers extremos nesta variável.

# %% [markdown]
# ### 4.1.2. HISTOGRAMA 'sepal width':

# %%
plt.figure(figsize=(8, 5))
plt.grid(True, linestyle='-', alpha=0.5)
sns.histplot(data=iris, x='sepal width (cm)', bins=20, kde=True)

plt.title('Distribuição da Largura da Sépala', fontsize=14)
plt.xlabel('Largura da Sépala (cm)')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📌 Interpretação: `sepal width (cm)`
#
# - A distribuição da largura da sépala mostra uma leve assimetria, com a maioria dos valores concentrados entre 2,8 e 3,4 cm.
#
# - É possível notar um número pequeno de observações com valores abaixo de 2,5 cm, que podem representar outliers. A curva de densidade também sugere um leve achatamento da distribuição, indicando uma dispersão mais ampla dos dados.

# %% [markdown]
# ### 4.1.3. HISTOGRAMA 'petal lenght':

# %%
plt.figure(figsize=(8, 5))
plt.grid(True, linestyle='-', alpha=0.5)
sns.histplot(data=iris, x='petal length (cm)', bins=20, kde=True)

plt.title('Distribuição do Comprimento da Pétala', fontsize=14)
plt.xlabel('Comprimento da Pétala (cm)')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📌 Interpretação: `petal length (cm)`
#
# A variável `petal length (cm)` apresenta uma distribuição **bimodal clara**, com dois grupos distintos de valores:
#
# - Um grupo com comprimentos entre 1 e 2;
# - Outro entre 4 e 6 cm.
#
# Essa separação sugere que o comprimento da pétala é uma variável altamente discriminativa entre as espécies de flores, sendo potencialmente útil em tarefas de classificação.

# %% [markdown]
# ### 4.1.4. HISTOGRAMA 'petal width':

# %%
plt.figure(figsize=(8, 5))
plt.grid(True, linestyle='-', alpha=0.5)
sns.histplot(data=iris, x='petal width (cm)', bins=20, kde=True)

plt.title('Distribuição da Largura da Pétala', fontsize=14)
plt.xlabel('Largura da Pétala (cm)')
plt.ylabel('Frequência')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📌 Interpretação: `petal width (cm)`
#
# A largura da pétala apresenta uma distribuição com **três grupos visuais bem definidos**, o que indica grande potencial dessa variável para diferenciar espécies. Os três grupos são:
#
# - Valores próximos de 0,2 cm;
# - Valores intermediários de 1,0 a 1,5 cm;
# - Valores acima de 1,5 cm.
#
# Essa distribuição reforça que `petal width` pode ser um dos atributos mais relevantes para modelos de classificação com esse conjunto de dados.

# %% [markdown]
# ## 4.2. BOXPLOT:

# %% [markdown]
# ### 4.2.1. BOXPLOT 'sepal lenght' POR 'species':

# %%
plt.figure(figsize=(8, 5))
plt.grid(True, linestyle='-', alpha=0.5)
sns.boxplot(data=iris, x='species', y='sepal length (cm)')

plt.title('Comprimento da Sépala por Espécie', fontsize=14)
plt.xlabel('Espécie')
plt.ylabel('Comprimento da Sépala (cm)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📌 Interpretação: `sepal length (cm)` por espécie
#
# - A espécie *Setosa* possui sépalas visivelmente mais curtas, com baixa variação.
# - A espécie *Virginica* tem os maiores valores de comprimento da sépala e também maior dispersão.
# - A espécie *Versicolor* tem valores medianos de comprimento da sépala com dispersão grande.
#
# Há sobreposição parcial entre as distribuições de *Versicolor* e *Virginica*, o que pode dificultar a separação entre essas duas espécies com base apenas nessa variável.

# %% [markdown]
# ### 4.2.2. BOXPLOT DE 'sepal wigth' POR 'species':

# %%
plt.figure(figsize=(8, 5))
plt.grid(True, linestyle='-', alpha=0.5)
sns.boxplot(data=iris, x='species', y='sepal width (cm)')

plt.title('Largura da Sépala por Espécie', fontsize=14)
plt.xlabel('Espécie')
plt.ylabel('Largura da Sépala (cm)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📌 Interpretação: `sepal width (cm)` por espécie
#
# - A espécie *Setosa* apresenta a maior mediana de largura da sépala entre as três classes, além de uma distribuição mais concentrada e simétrica.
#
# - As espécies *Versicolor* e *Virginica* possuem distribuições semelhantes, com *Virginica* apresentando maior dispersão e alguns possíveis outliers com valores baixos.
#
# Essa variável mostra algum poder discriminativo, mas com menos clareza que outras como `petal length`.

# %% [markdown]
# ### 4.2.3. BOXPLOT DE 'petal lenght' POR 'species':

# %%
plt.figure(figsize=(8, 5))
plt.grid(True, linestyle='-', alpha=0.5)
sns.boxplot(data=iris, x='species', y='petal length (cm)')

plt.title('Comprimento da Pétala por Espécie', fontsize=14)
plt.xlabel('Espécie')
plt.ylabel('Comprimento da Pétala (cm)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📌 Interpretação: `petal length (cm)` por espécie
#
# O comprimento da pétala é a variável com **maior poder discriminativo** entre as espécies:
#
# - *Setosa* possui pétalas curtas, com valores concentrados abaixo de 2 cm;
# - *Versicolor* ocupa uma faixa intermediária, entre 3 e 5 cm;
# - *Virginica* apresenta os maiores valores, geralmente acima de 5 cm.
#
# As distribuições não se sobrepõem, tornando essa variável altamente eficaz para a separação entre classes em um modelo de classificação.

# %% [markdown]
# ### 4.2.4. BOXPLOT DE 'petal width' POR 'species':

# %%
plt.figure(figsize=(8, 5))
plt.grid(True, linestyle='-', alpha=0.5)
sns.boxplot(data=iris, x='species', y='petal width (cm)')

plt.title('Largura da Pétala por Espécie', fontsize=14)
plt.xlabel('Espécie')
plt.ylabel('Largura da Pétala (cm)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 📌 Interpretação: `petal width (cm)` por espécie
#
# A largura da pétala também mostra alto poder discriminativo:
#
# - *Setosa* apresenta valores muito baixos e concentrados (~0,2 cm), com distribuição estreita;
# - *Versicolor* tem distribuição intermediária, geralmente entre 1 e 1,5 cm;
# - *Virginica* possui maior variação, com valores de 1,5 a quase 2,5 cm.
#
# Apesar de uma leve sobreposição entre *Versicolor* e *Virginica*, essa variável continua sendo uma excelente candidata para separar classes em uma análise supervisionada.

# %% [markdown]
# # 5. CONCLUSÃO:

# %% [markdown]
# # 📝 Conclusão
#
# Neste notebook, realizamos uma análise univariada detalhada das variáveis numéricas do clássico dataset Iris, utilizando visualizações gráficas como histogramas e boxplots para explorar as distribuições e dispersões das medidas das flores.
#
# Ficou claro que variáveis como `petal length (cm)` e `petal width (cm)` apresentam forte poder discriminativo para distinguir as espécies, enquanto `sepal length (cm)` e `sepal width (cm)` apresentam sobreposições que podem dificultar essa separação.
#
# ---
#
# # 🚀 Próximos passos
#
# Para dar continuidade ao projeto, recomenda-se:
#
# - Avançar para análises bivariadas e multivariadas, explorando relações entre variáveis e agrupamentos por espécie.
# - Aplicar técnicas de visualização mais avançadas, como pairplots, scatter plots com hue e gráficos de violino.
# - Desenvolver modelos preditivos simples para classificação, utilizando as variáveis exploradas.
# - Documentar o código e os insights de forma clara para um portfólio profissional.
#
# Esse notebook pode ser a base inicial de uma série consistente que mostra seu domínio em análise exploratória e visualização de dados.
